# %% [markdown]
# # Visualizing Earnings Based On College Majors
#
# In this project, we'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by [American Community Survey](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/tree/master/college-majors).
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# - Rank - Rank by median earnings (the dataset is ordered by this column).
# - Major_code - Major code.
# - Major - Major description.
# - Major_category - Category of major.
# - Total - Total number of people with major.
# - Sample_size - Sample size (unweighted) of full-time.
# - Men - Male graduates.
# - Women - Female graduates.
# - ShareWomen - Women as share of total.
# - Employed - Number employed.
# - Median - Median salary of full-time, year-round workers.
# - Low_wage_jobs - Number in low-wage service jobs.
# - Full_time - Number employed 35 hours or more.
# - Part_time - Number employed less than 35 hours.
#
# Let's start by setting up our environment by impoting the libraries we will need and reading the dataset into a DataFrame

# %%
#importing the necessary libraries
import pandas as pd
import matplotlib as plt
# %matplotlib inline

#reading and exploring the data
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print('\n')
print(recent_grads.head())
print('\n')
print(recent_grads.tail())
print('\n')
recent_grads.describe()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# ## Deleting Rows With Missing Values
#
# Because Matplotlib expects that columns of values we pass in have matching lengths and missing values will cause matplotlib to throw errors, our next step will be to drop any row that contain a missing value.

# %%
raw_data_count = recent_grads.shape
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape
print('The number of rows and columns in our raw data was: ',raw_data_count)
print('The number of rows and columns after deleting the rows with missing values is: ', cleaned_data_count)
# Out:
# The number of rows and columns in our raw data was:  (173, 21)
# The number of rows and columns after deleting the rows with missing values is:  (172, 21)

# %% [markdown]
# ### Scatter Plots
#
#
# - **Sample_size and Median**

# %%
recent_grads.plot(x= 'Sample_size', y= 'Median', kind= 'scatter')

# %% [markdown]
# - **Sample_size and Unemployment_rate**

# %%
recent_grads.plot(x= 'Sample_size', y= 'Unemployment_rate', kind= 'scatter')

# %% [markdown]
# - **Full time and Median**

# %%
recent_grads.plot(x= 'Full_time', y= 'Median', kind = 'scatter')

# %% [markdown]
# - **Share Women and Unemployment_rate**

# %%
recent_grads.plot(x= 'ShareWomen', y= 'Unemployment_rate', kind= 'scatter')

# %% [markdown]
# - **Men and Median**

# %%
recent_grads.plot(x= 'Men', y= 'Median', kind= 'scatter')

# %% [markdown]
# - **Women and Median**

# %%
recent_grads.plot(x= 'Women', y= 'Median', kind= 'scatter')

# %% [markdown]
# ## Histograms
#
# - **Sample_size**

# %%
recent_grads['Sample_size'].plot(kind= 'hist')

# %% [markdown]
# - **Median**

# %%
recent_grads['Median'].plot(kind= 'hist')

# %% [markdown]
# - **Employed**

# %%
recent_grads['Employed'].plot(kind= 'hist')

# %% [markdown]
# - **Full time**

# %%
recent_grads['Full_time'].plot(kind= 'hist')

# %% [markdown]
# - ** ShareWomen**

# %%
recent_grads['ShareWomen'].plot(kind= 'hist')

# %% [markdown]
# - **Unemployment_rate**

# %%
recent_grads['Unemployment_rate'].plot(kind= 'hist')

# %% [markdown]
# - **Men**

# %%
recent_grads['Men'].plot(kind= 'hist')

# %% [markdown]
# - **Women**

# %%
recent_grads['Women'].plot(kind= 'hist')

# %% [markdown]
# ## Scatter Matrix Plots
#
# - **Sample_size and Median**

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize= (7,7))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe77529bb38>,
# ...
#       dtype=object)

# %% [markdown]
# - **Sample_size, Median anf Unemployem

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize = (8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe775100860>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar Plot
#
# - **Percentages of Women**

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %% [markdown]
# - **Unemployment rate**

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=False)
